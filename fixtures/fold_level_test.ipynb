# %% [markdown]
# # Level 1 - Alpha

# %%
print('alpha body')

# %% [markdown]
# ## Level 2 - Alpha.1

# %%
print('alpha.1 body')

# %% [markdown]
# ### Level 3 - Alpha.1.a

# %%
print('alpha.1.a body')

# %% [markdown]
# ## Level 2 - Alpha.2

# %%
print('alpha.2 body')

# %% [markdown]
# # Level 1 - Beta

# %%
print('beta body')

# %% [markdown]
# Plain markdown, no header at all

# %% [markdown]
# ## Level 2 - Beta.1

# %%
print('beta.1 body')
