# %% [markdown]
# ### Load raw data

# %%
import pandas as pd
import numpy as np

# step: load_raw_data
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21

# %% [markdown]
# ### Quality control

# %%
import pandas as pd
import numpy as np

# step: quality_control
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21
value_22 = np.arange(22) * 22
value_23 = np.arange(23) * 23
value_24 = np.arange(24) * 24
value_25 = np.arange(25) * 25
value_26 = np.arange(26) * 26
value_27 = np.arange(27) * 27
value_28 = np.arange(28) * 28
value_29 = np.arange(29) * 29

# %% [markdown]
# ### Derive features

# %%
import pandas as pd
import numpy as np

# step: derive_features
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21
value_22 = np.arange(22) * 22
value_23 = np.arange(23) * 23
value_24 = np.arange(24) * 24

# %% [markdown]
# ### Fit baseline model

# %%
import pandas as pd
import numpy as np

# step: fit_baseline_model
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21
value_22 = np.arange(22) * 22
value_23 = np.arange(23) * 23
value_24 = np.arange(24) * 24
value_25 = np.arange(25) * 25
value_26 = np.arange(26) * 26
value_27 = np.arange(27) * 27

# %% [markdown]
# ### Cross validation

# %%
import pandas as pd
import numpy as np

# step: cross_validation
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19

# %% [markdown]
# ### Compare models

# %%
import pandas as pd
import numpy as np

# step: compare_models
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21
value_22 = np.arange(22) * 22
value_23 = np.arange(23) * 23

# %% [markdown]
# ### Export results

# %% [markdown]
# Free-form notes with no heading, so the extension must skip it
# when deciding what to fold (line 2).
# when deciding what to fold (line 3).
# when deciding what to fold (line 4).
# when deciding what to fold (line 5).
# when deciding what to fold (line 6).
# when deciding what to fold (line 7).

# %%
import pandas as pd
import numpy as np

# step: final_report
value_4 = np.arange(4) * 4
value_5 = np.arange(5) * 5
value_6 = np.arange(6) * 6
value_7 = np.arange(7) * 7
value_8 = np.arange(8) * 8
value_9 = np.arange(9) * 9
value_10 = np.arange(10) * 10
value_11 = np.arange(11) * 11
value_12 = np.arange(12) * 12
value_13 = np.arange(13) * 13
value_14 = np.arange(14) * 14
value_15 = np.arange(15) * 15
value_16 = np.arange(16) * 16
value_17 = np.arange(17) * 17
value_18 = np.arange(18) * 18
value_19 = np.arange(19) * 19
value_20 = np.arange(20) * 20
value_21 = np.arange(21) * 21
value_22 = np.arange(22) * 22
value_23 = np.arange(23) * 23
value_24 = np.arange(24) * 24
value_25 = np.arange(25) * 25
value_26 = np.arange(26) * 26
value_27 = np.arange(27) * 27
value_28 = np.arange(28) * 28
value_29 = np.arange(29) * 29
